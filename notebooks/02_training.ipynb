# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import joblib
from pathlib import Path
import sys

project_root = Path.cwd().parent
sys.path.append(str(project_root))

data = np.load(project_root / 'features.npz')
X = data['X']
y_emotion = data['y_emotion']

print("Загружено признаков:", X.shape)
# Out:
# Загружено признаков: (50000, 43)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_emotion, test_size=0.2, random_state=42, stratify=y_emotion)

model = RandomForestClassifier(n_estimators=200, max_depth=30, random_state=42, n_jobs=-1)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, zero_division=0))

joblib.dump(model, project_root / 'models' / 'emotion_model.pkl')
print("Модель эмоций сохранена в models/emotion_model.pkl")
# Out:
# Accuracy: 0.6712
#               precision    recall  f1-score   support
#
#        angry       0.50      0.01      0.02      1024
#      neutral       0.67      1.00      0.80      6513
#        other       0.98      0.45      0.62       102
#     positive       0.67      0.07      0.12       955
#          sad       0.89      0.08      0.14      1406
#
#     accuracy                           0.67     10000
#    macro avg       0.74      0.32      0.34     10000
# weighted avg       0.68      0.67      0.56     10000
#
# Модель эмоций сохранена в models/emotion_model.pkl
